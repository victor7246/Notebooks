# %% [markdown]
# ### Syntax
#
# Syntax is the structure of a language which is governed by grammers. Any ordering of words can not be a sentence. Hence, we need syntactical analysis for natural languages.
#
# ## Table of Contents
#
# * [Parts of Speech Tagging](#pos)
# * [Dependency Parsing](#parsing)
# * [Named Entity Recognition](#ner)

# %% [markdown]
# <a id='pos'></a>
#
# ### Parts of Speech Tagging
#
# Parts of speech (POS) are specific lexical categories to which words are assigned, based on their syntactic context and role. Usually, words can fall into one of the following major categories.
#
# * <strong>Nouns</strong>
# * <strong>Verb</strong>
# * <strong>Adjective</strong>
# * <strong>Adverb</strong>
#
# Besides these four major categories of parts of speech , there are other categories that occur frequently in the English language. These include pronouns, prepositions, interjections, conjunctions, determiners, and many others. The process of classifying and labeling POS tags for words called parts of speech tagging or POS tagging . POS tags are used to annotate words and depict their POS, which is really helpful to perform specific analysis, such as narrowing down upon nouns and seeing which ones are the most prominent, word sense disambiguation, and grammar analysis.

# %%
import pandas as pd

pd.options.display.max_colwidth = -1

data = pd.read_csv('clinical_notes_cleaned.csv') #for excel file use read_excel

# %%
import nltk
import spacy
import en_core_med7_lg #en_core_web_sm
import re

nlp = spacy.load('en_core_med7_lg', parse=True, tag=True, entity=True)

# %%
sample_text = data.clean_text.iloc[1]
print (sample_text)
# Out:
# preoperative ganglion left wrist . postoperative ganglion left wrist . excision ganglion . general . estimate blood less 5 ml . successful anesthetic , patient position operating table . tourniquet apply upper arm . extremity preppe usual manner surgical procedure drape . superficial vessel exsanguinate elastic wrap tourniquet inflate usual arm pressure . curved incision make present ganglion dorsal aspect wrist . blunt sharp dissection , dissect underneath extensor tendon stalk appear arise distal radiocapitellar joint dorsal capsule excise along ganglion specimen remove submit . small superficial vessel electrocoagulate instill close skin 4 - 0 prolene , area approximately 6 7 ml 0.25 marcaine epinephrine . jackson - pratt drain insert tourniquet release , keep deflate least 5 10 minute pass activate remove recovery room . dressing apply hand xeroform , 4x4s , abd , kerlix , elastic wrap volar fiberglass splint . tourniquet release . circulation return finger . patient allow awaken leave operating room good condition .

# %%
text_tokenized = nlp(sample_text)

for token in text_tokenized:
    print ("{} ---> {}".format(token,token.pos_))
# Out:
# preoperative ---> ADJ
# ganglion ---> NOUN
# left ---> VERB
# wrist ---> NOUN
# . ---> PUNCT
# postoperative ---> ADJ
# ganglion ---> NOUN
# left ---> VERB
# wrist ---> NOUN
# . ---> PUNCT
# excision ---> NOUN
# ganglion ---> NOUN
# . ---> PUNCT
# general ---> PROPN
# . ---> PUNCT
# estimate ---> VERB
# blood ---> NOUN
# less ---> ADJ
# 5 ---> NUM
# ml ---> NOUN
# . ---> PUNCT
# successful ---> ADJ
# anesthetic ---> NOUN
# , ---> PUNCT
# patient ---> ADJ
# position ---> NOUN
# operating ---> VERB
# table ---> NOUN
# . ---> PUNCT
# tourniquet ---> NOUN
# apply ---> VERB
# upper ---> ADJ
# arm ---> NOUN
# . ---> PUNCT
# extremity ---> NOUN
# preppe ---> ADJ
# usual ---> ADJ
# manner ---> ADJ
# surgical ---> ADJ
# procedure ---> NOUN
# drape ---> NOUN
# . ---> PUNCT
# superficial ---> ADJ
# vessel ---> NOUN
# exsanguinate ---> ADJ
# elastic ---> ADJ
# wrap ---> NOUN
# tourniquet ---> NOUN
# inflate ---> VERB
# usual ---> ADJ
# arm ---> NOUN
# pressure ---> NOUN
# . ---> PUNCT
# curved ---> ADJ
# incision ---> NOUN
# make ---> VERB
# present ---> ADJ
# ganglion ---> NOUN
# dorsal ---> ADJ
# aspect ---> NOUN
# wrist ---> NOUN
# . ---> PUNCT
# blunt ---> ADJ
# sharp ---> ADJ
# dissection ---> NOUN
# , ---> PUNCT
# dissect ---> VERB
# underneath ---> ADP
# extensor ---> ADJ
# tendon ---> NOUN
# stalk ---> NOUN
# appear ---> VERB
# arise ---> VERB
# distal ---> ADJ
# radiocapitellar ---> ADJ
# joint ---> ADJ
# dorsal ---> ADJ
# capsule ---> NOUN
# excise ---> NOUN
# along ---> ADP
# ganglion ---> NOUN
# specimen ---> NOUN
# remove ---> VERB
# submit ---> VERB
# . ---> PUNCT
# small ---> ADJ
# superficial ---> ADJ
# vessel ---> NOUN
# electrocoagulate ---> ADJ
# instill ---> VERB
# close ---> ADJ
# skin ---> NOUN
# 4 ---> NUM
# - ---> SYM
# 0 ---> NUM
# prolene ---> NOUN
# , ---> PUNCT
# area ---> NOUN
# approximately ---> ADV
# 6 ---> NUM
# 7 ---> NUM
# ml ---> NUM
# 0.25 ---> NUM
# marcaine ---> NOUN
# epinephrine ---> NOUN
# . ---> PUNCT
# jackson ---> PROPN
# - ---> PUNCT
# pratt ---> PROPN
# drain ---> PROPN
# insert ---> NOUN
# tourniquet ---> NOUN
# release ---> NOUN
# , ---> PUNCT
# keep ---> VERB
# deflate ---> VERB
# least ---> ADV
# 5 ---> NUM
# 10 ---> NUM
# minute ---> NOUN
# pass ---> NOUN
# activate ---> VERB
# remove ---> VERB
# recovery ---> NOUN
# room ---> NOUN
# . ---> PUNCT
# dressing ---> VERB
# apply ---> VERB
# hand ---> PROPN
# xeroform ---> PROPN
# , ---> PUNCT
# 4x4s ---> NUM
# , ---> PUNCT
# abd ---> PROPN
# , ---> PUNCT
# kerlix ---> PROPN
# , ---> PUNCT
# elastic ---> ADJ
# wrap ---> NOUN
# volar ---> ADJ
# fiberglass ---> NOUN
# splint ---> NOUN
# . ---> PUNCT
# tourniquet ---> NOUN
# release ---> NOUN
# . ---> PUNCT
# circulation ---> NOUN
# return ---> NOUN
# finger ---> NOUN
# . ---> PUNCT
# patient ---> NOUN
# allow ---> VERB
# awaken ---> VERB
# leave ---> NOUN
# operating ---> NOUN
# room ---> NOUN
# good ---> ADJ
# condition ---> NOUN
# . ---> PUNCT

# %% [markdown]
# Usually POS tags are used for analysis, feature engineering or, feature selection. In this analysis, let us select only the words that are nouns, verbs, number and adjectives.

# %%
def get_selected_pos(text):
    text_tokenized = nlp(text)
    selected_words = [token.string for token in text_tokenized if token.pos_ in ['NOUN','PROPN','NUM','ADJ','VERB','PUNCT']]
    processed_text = re.sub(' +',' ', " ".join(selected_words))
    return processed_text

# %%
data = data.dropna(subset=['clean_text'])
data.clean_text = data.clean_text.apply(get_selected_pos)

# %% [markdown]
# <a id='parsing'></a>
#
# ### Dependency Parsing
#
# In dependency parsing, we try to use dependency-based grammars to analyze and infer both structure and semantic dependencies and relationships between tokens in a sentence. The basic principle behind a dependency grammar is that in any sentence in the language, all words except one, have some relationship or dependency on other words in the sentence. The word that has no dependency is called the root of the sentence. The verb is taken as the root of the sentence in most cases. All the other words are directly or indirectly linked to the root verb using links , which are the dependencies.

# %%
from spacy import displacy

text_tokenized = nlp(data.clean_text.iloc[1])

options = {"compact": True}
displacy.serve(text_tokenized, style="dep", options=options)

#displacy.render(text_tokenized, jupyter=True, 
#                options={'distance': 110,
#                         'arrow_stroke': 2,
#                         'arrow_width': 8})
# Out:
# C:\Users\asengup6\Softwares\Anaconda\Lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a770aee52d464151b8c8cbcd99c8db05-0" class="displacy" width="19250" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">preoperative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">ganglion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">left</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">wrist .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">postoperative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">ganglion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">left</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">wrist .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">excision</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">ganglion .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">general .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">estimate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">blood</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">less</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">ml .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">successful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">anesthetic ,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">patient</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">position</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">operating</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">table .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">tourniquet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">apply</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">upper</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">arm .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">extremity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">preppe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">usual</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" t
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# <a id='ner'></a>
#
# ### Named Entity Recognition (NER)
#
# In any text document, there are particular terms that represent specific entities that are more informative and have a unique context. These entities are known as named entities , which more specifically refer to terms that represent real-world objects like people, places, organizations, and so on, which are often denoted by proper names. A naive approach could be to find these by looking at the noun phrases in text documents. Named entity recognition (NER) , also known as entity chunking/extraction , is a popular technique used in information extraction to identify and segment the named entities and classify or categorize them under various predefined classes.

# %%
#for ent in text_tokenized.ents:
#    print ("{} ---> {}".format(ent.text, ent.label_))
    
displacy.serve(text_tokenized, style="ent")
# Out:
# 0.25 ---> STRENGTH
# marcaine epinephrine ---> DRUG
# C:\Users\asengup6\Softwares\Anaconda\Lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">preoperative ganglion left wrist . postoperative ganglion left wrist . excision ganglion . general . estimate blood less 5 ml . successful anesthetic , patient position operating table . tourniquet apply upper arm . extremity preppe usual manner surgical procedure drape . superficial vessel exsanguinate elastic wrap tourniquet inflate usual arm pressure . curved incision make present ganglion dorsal aspect wrist . blunt sharp dissection , dissect extensor tendon stalk appear arise distal radiocapitellar joint dorsal capsule excise ganglion specimen remove submit . small superficial vessel electrocoagulate instill close skin 4 0 prolene , area 6 7 ml
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">STRENGTH</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     marcaine epinephrine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  . jackson - pratt drain insert tourniquet release , keep deflate 5 10 minute pass activate remove recovery room . dressing apply hand xeroform , 4x4s , abd , kerlix , elastic wrap volar fiberglass splint . tourniquet release . circulation return finger . patient allow awaken leave operating room good condition .</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
text_tokenized_orig = nlp(data.text.iloc[1])
#for ent in text_tokenized_orig_eng.ents:
#    print ("{} ---> {}".format(ent.text, ent.label_))
    
displacy.serve(text_tokenized_orig, style="ent")
# Out:
# C:\Users\asengup6\Softwares\Anaconda\Lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr"></br> </br> </br> </br> </br> &lt;B&gt;PREOPERATIVE DIAGNOSIS: &lt;/B&gt; Ganglion of the left wrist.</br> </br> &lt;B&gt;POSTOPERATIVE DIAGNOSIS: &lt;/B&gt; Ganglion of the left wrist.</br> </br> &lt;B&gt;OPERATION: &lt;/B&gt; Excision of ganglion.</br> </br> &lt;B&gt;ANESTHESIA: &lt;/B&gt; General.</br> </br> &lt;B&gt;ESTIMATED BLOOD LOSS: &lt;/B&gt; Less than 5 mL.</br> </br> &lt;B&gt;OPERATION: &lt;/B&gt; After a successful anesthetic, the patient was positioned on the operating table.  A tourniquet applied to the upper arm.  The extremity was prepped in a usual manner for a surgical procedure and draped off.  The superficial vessels were exsanguinated with an elastic wrap and the tourniquet was then inflated to the usual arm pressure.  A curved incision was made over the presenting ganglion over the dorsal aspect of the wrist.  By blunt and sharp dissection, it was dissected out from underneath the extensor tendons and the stalk appeared to arise from the distal radiocapitellar joint and the dorsal capsule was excised along with the ganglion and the specimen was removed and submitted.  The small superficial vessels were electrocoagulated and instilled after closing the skin with 4-0 Prolene, into the area was approximately 6 to 7 mL of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">STRENGTH</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Marcaine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
#  with
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     epinephrine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DRUG</span>
# </mark>
# .  A Jackson-Pratt drain was inserted and then after the tourniquet was released, it was kept deflated until at least 5 to 10 minutes had passed and then it was activated and then removed in the recovery room.  The dressings applied to the hand were that of Xeroform, 4x4s, ABD, Kerlix, and elastic wrap over a volar fiberglass splint.  The tourniquet was released.  Circulation returned to the fingers.  The patient then was allowed to awaken and left the operating room in good condition.
#
#
#
#
#
#
#
# </div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
nlp_eng = spacy.load('en_core_web_sm', parse=True, tag=True, entity=True)
text_tokenized_eng = nlp_eng(data.clean_text.iloc[1])
#for ent in text_tokenized_eng.ents:
#    print ("{} ---> {}".format(ent.text, ent.label_))
    
displacy.serve(text_tokenized_eng, style="ent")
# Out:
# C:\Users\asengup6\Softwares\Anaconda\Lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">preoperative ganglion left wrist . postoperative ganglion left wrist . excision ganglion . general . estimate blood less
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 ml
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  . successful anesthetic , patient position operating table . tourniquet apply upper arm . extremity preppe usual manner surgical procedure drape . superficial vessel exsanguinate elastic wrap tourniquet inflate usual arm pressure . curved incision make present ganglion dorsal aspect wrist . blunt sharp dissection , dissect extensor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tendon stalk
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  appear
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     arise distal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  radiocapitellar joint dorsal capsule excise ganglion specimen remove submit . small superficial vessel electrocoagulate instill close skin
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  0 prolene , area
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6 7 ml 0.25 marcaine epinephrine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jackson - pratt
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  drain insert tourniquet release , keep deflate
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 10 minute
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  pass activate remove recovery room . dressing apply hand xeroform ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4x4s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abd
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , kerlix , elastic wrap volar fiberglass splint . tourniquet release . circulation return finger . patient allow awaken leave operating room good condition .</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
text_tokenized_orig_eng = nlp_eng(data.text.iloc[1])
#for ent in text_tokenized_orig_eng.ents:
#    print ("{} ---> {}".format(ent.text, ent.label_))
    
displacy.serve(text_tokenized_orig_eng, style="ent")
# Out:
# C:\Users\asengup6\Softwares\Anaconda\Lib\runpy.py:193: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   "__main__", mod_spec)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr"></br> </br> </br> </br> </br> &lt;B&gt;PREOPERATIVE DIAGNOSIS: &lt;/B&gt; Ganglion of the left wrist.</br> </br> &lt;B&gt;POSTOPERATIVE DIAGNOSIS: &lt;/B&gt; Ganglion of the left wrist.</br> </br> &lt;B&gt;OPERATION: &lt;/B&gt; Excision of ganglion.</br> </br> &lt;B&gt;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ANESTHESIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# : &lt;/B&gt; General.</br> </br> &lt;B&gt;ESTIMATED BLOOD LOSS: &lt;/B&gt; Less than
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  mL.</br> </br> &lt;B&gt;OPERATION: &lt;/B&gt; After a successful anesthetic, the patient was positioned on the operating table.  A tourniquet applied to the upper arm.  The extremity was prepped in a usual manner for a surgical procedure and draped off.  The superficial vessels were exsanguinated with an elastic wrap and the tourniquet was then inflated to the usual arm pressure.  A curved incision was made over the presenting ganglion over the dorsal aspect of the wrist.  By blunt and sharp dissection, it was dissected out from underneath the extensor tendons and the stalk appeared to arise from the distal radiocapitellar joint and the dorsal capsule was excised along with the ganglion and the specimen was removed and submitted.  The small superficial vessels were electrocoagulated and instilled after closing the skin with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -0 Prolene, into the area was approximately
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  to
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7 mL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Marcaine with epinephrine.  A Jackson-Pratt drain was inserted and then after the tourniquet was released, it was kept deflated until
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     at least 5 to 10 minutes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  had passed and then it was activated and then removed in the recovery room.  The dressings applied to the hand were that of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Xeroform, 4x4s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ABD
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kerlix
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and elastic wrap over a volar fiberglass splint.  The tourniquet was released.  Circulation returned to the fingers.  The patient then was allowed to awaken and left the operating room in good condition.
#
#
#
#
#
#
#
# </div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
data.to_csv("clinical_notes_cleaned_pos.csv",index=False)

# %% [markdown]
# ### References for further reading
#
# <strong> POS tagging </strong>
#
# https://www.nltk.org/book/ch05.html
#
# <strong> Medical named entity recognition </strong>
#
# https://github.com/kormilitzin/med7
#
# https://github.com/NLPatVCU/medaCy
#
# https://github.com/text-machine-lab/CliNER
